# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Osmi
# ### Business Analyst

# %% [markdown]
# ### *I am interested in data science because we need to analyze historical data and predict new cases to take important actions.*

# %% [markdown]
# ### Multiplying two big number

# %%
multiply = 12412412*123123124
print(multiply)
# Out:
# 1528254941815088

# %% [markdown]
# ***
#
# output = 1528254941815088
#
# ***
# Our program website can be found at <a href="http://earthdatascience.org" target="_blank">this link</a>.
#
# `Here is some code!`
